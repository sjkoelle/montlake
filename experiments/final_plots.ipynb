# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = 1000
r = np.random.uniform(low=0, high=1, size=n)  # radius
theta = np.random.uniform(low=0, high=2*np.pi, size=n)  # angle
x = np.sqrt(r) * np.cos(theta)
y = np.sqrt(r) * np.sin(theta)
fg, ax = plt.subplots(1, 1)
ax.scatter(x, y, c= x, cmap = 'viridis') # plot random points

# %%
fg, ax = plt.subplots(1, 1)
ax.scatter(x, y, c= y, cmap = 'viridis')

# %%
np.asarray([[1.,0],[.9,0],[.5,0]])
